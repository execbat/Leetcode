# %% [markdown]
# 98. Validate Binary Search Tree

# %% [markdown]
# Given the root of a binary tree, determine if it is a valid binary search tree (BST).
#
# A valid BST is defined as follows:
#
# The left
# subtree
#  of a node contains only nodes with keys less than the node's key.
# The right subtree of a node contains only nodes with keys greater than the node's key.
# Both the left and right subtrees must also be binary search trees.

# %% [markdown]
# ![image.png](attachment:e72f371a-ab93-4610-9470-d241a159c980.png)

# %% [markdown]
# ![image.png](attachment:1cffbf17-d5f1-4b5c-8457-2b9e4c32ab09.png)

# %%
class Solution(object):
    def isValidBST(self, root, low_lim = -10**4, high_lim = 10**4):
        if not root:
            return True

        if not low_lim < root.val < high_lim:
            return False

        return self.isValidBST(root.left, low_lim , root.val) and  self.isValidBST(root.right, root.val, high_lim)

# %%
# Development

# %%
root = [5,1,4,"null","null",3,6]

# %%
# Definition of TreeNode class

class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
# Helper function to build the Tree from list representation

from collections import deque

def build_tree_by_levels(list_obj):
    if len(list_obj) == 0:
        return None

    root = TreeNode(list_obj[0])
    q = deque()
    q.append(root)
    i = 1

    while q and i < len(list_obj):
        node = q.popleft()
        
        if (i < len(list_obj)) and (list_obj[i] != 'null'):
            node.left = TreeNode(list_obj[i])
            q.append(node.left)

        i += 1
        if (i < len(list_obj)) and (list_obj[i] != 'null'):
            node.right = TreeNode(list_obj[i])
            q.append(node.right)

        i += 1

    return root

            
tree = build_tree_by_levels(root)

# %%
# Testing the function

import math

def isValidBST(tree, low_lim = -math.inf, high_lim = +math.inf):
    if not tree:
        return True

    if not low_lim < tree.val < high_lim:
        return False

    return isValidBST(tree.left, low_lim , tree.val) and  isValidBST(tree.right, tree.val, high_lim) 
    
isValidBST(tree)
# Out:
# False
