# %% [markdown]
# 20. Valid Parentheses

# %% [markdown]
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
# Every close bracket has a corresponding open bracket of the same type.

# %% [markdown]
# ![image.png](attachment:1069350e-6964-4c08-9e25-74dd0fcebe7e.png)

# %%
class Solution(object):
    def isValid(self, s):
        """
        :type s: str
        :rtype: bool
        """
        
        if len(s) %2 != 0:
            return False
        
        q = deque()
        for i, char in enumerate(s):
            if char in ["(", "[", "{"]:
                q.append(char)

            else:
                if q:
                    if (char == ")" and q[-1] == "(") or  (char == "]" and q[-1] == "[") or (char == "}" and q[-1] == "{"):
                        q.pop()

                    else:
                        return False
                else:
                    return False

        return len(q) == 0

# %%
# Development

# %%
s = "(){}}{"

# %%
from collections import deque

def check_brackets(s):
    if len(s) %2 != 0:
        return False
    
    q = deque()
    for i, char in enumerate(s):
        if char in ["(", "[", "{"]:
            q.append(char)

        else:
            if q:
                if (char == ")" and q[-1] == "(") or  (char == "]" and q[-1] == "[") or (char == "}" and q[-1] == "{"):
                    q.pop()

                else:
                    return False
            else:
                return False


    return len(q) == 0

# %%
check_brackets(s)
# Out:
# False
