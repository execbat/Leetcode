# %% [markdown]
# 14. Longest Common Prefix

# %% [markdown]
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".

# %% [markdown]
# ![image.png](attachment:6d29feab-abae-4d51-9787-9f7c2b0bc347.png)

# %%
class Solution(object):
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        if len (strs) == 1:
            return strs[0]
            
        def helper(idx = 0):
            try:
                elems = [i[idx] for i in strs]
                
            except IndexError:
                return idx
        
            if len(set(elems)) != 1:
                return idx
            return helper(idx + 1)

        res = helper(idx = 0)
        return strs[0][: res]

# %%
# Development

# %%
# Input: 
strs = ["flower","flow","flight"]
# Output: "fl"

# %%
def common_prefix(strs):
    if len (strs) == 1:
        return strs[0]
        
    def helper(idx = 0):
        try:
            elems = [i[idx] for i in strs]
            
        except IndexError:
            return idx
    
        if len(set(elems)) != 1:
            return idx
        return helper(idx + 1)

    res = helper(idx = 0)
    return strs[0][: res]

# %%
common_prefix(strs)
# Out:
# 'fl'
