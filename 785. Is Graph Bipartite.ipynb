# %% [markdown]
# 785. Is Graph Bipartite?

# %% [markdown]
# There is an undirected graph with n nodes, where each node is numbered between 0 and n - 1. You are given a 2D array graph, where graph[u] is an array of nodes that node u is adjacent to. More formally, for each v in graph[u], there is an undirected edge between node u and node v. The graph has the following properties:
#
# There are no self-edges (graph[u] does not contain u).
# There are no parallel edges (graph[u] does not contain duplicate values).
# If v is in graph[u], then u is in graph[v] (the graph is undirected).
# The graph may not be connected, meaning there may be two nodes u and v such that there is no path between them.
# A graph is bipartite if the nodes can be partitioned into two independent sets A and B such that every edge in the graph connects a node in set A and a node in set B.
#
# Return true if and only if it is bipartite.

# %% [markdown]
# ![image.png](attachment:82cd5200-e385-46de-a42a-9b5aa386d390.png)

# %% [markdown]
# ![image.png](attachment:3beb3628-02d8-43d9-a4b8-ce49354e3f54.png)

# %% [markdown]
# ![image.png](attachment:06df5588-26dd-463d-af1b-04e41de03dbc.png)

# %%
class Solution(object):
    def isBipartite(self, g):
        """
        :type graph: List[List[int]]
        :rtype: bool
        """
        colors = [-1]*len(g) 

        for start in range(len(g)):
            if colors[start] == -1:
                colors[start] = 0
                q = deque([start])
            
                while q:
                    v = q.popleft()
                    for neighbor in g[v]:
                        if colors[neighbor] == -1:
                            colors[neighbor] = 1 - colors[v]
                            q.append(neighbor)
            
                        elif colors[neighbor] == colors[v]:
                            return False

        return True

# %%
# Development

# %%
graph = [[],[2,4,6],[1,4,8,9],[7,8],[1,2,8,9],[6,9],[1,5,7,8,9],[3,6,9],[2,3,4,6,9],[2,4,5,6,7,8]]

# %%
# Help function to build graph into dict view
def build_graph(graph):
    g = dict()
    for v, neighbours in enumerate(graph):
        if not v in graph:
            g[v] = neighbours
        else:
            g[v].append(*neighbours)
    return g

# %%
g = build_graph(graph)
g
# Out:
# {0: [],
#  1: [2, 4, 6],
#  2: [1, 4, 8, 9],
#  3: [7, 8],
#  4: [1, 2, 8, 9],
#  5: [6, 9],
#  6: [1, 5, 7, 8, 9],
#  7: [3, 6, 9],
#  8: [2, 3, 4, 6, 9],
#  9: [2, 4, 5, 6, 7, 8]}

# %%
from collections import deque

def isBiparite(g):          
    colors = [-1]*len(g) 

    for start in range(len(g)):
        if colors[start] == -1:
            colors[start] = 0
            q = deque([start])
        
            while q:
                v = q.popleft()
                for neighbor in g[v]:
                    if colors[neighbor] == -1:
                        colors[neighbor] = 1 - colors[v]
                        q.append(neighbor)
        
                    elif colors[neighbor] == colors[v]:
                        return False

    return True
 
isBiparite(g)
# Out:
# False
