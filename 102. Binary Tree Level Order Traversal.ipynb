# %% [markdown]
# 102. Binary Tree Level Order Traversal

# %% [markdown]
# Given the root of a binary tree, return the level order traversal of its nodes' values. (i.e., from left to right, level by level).

# %% [markdown]
# ![image.png](attachment:032b769c-4008-4153-a366-ffd974730405.png)

# %% [markdown]
# ![image.png](attachment:c1d2b10f-dfec-4cc2-a5dc-531e5bb298e0.png)

# %%
class Solution(object):
    def levelOrder(self, tree):
        if not tree:
            return []

        result_list = []
        q = deque([tree])

        while q:
            objects_in_level = len(q)        
            level = []

            for _ in range(objects_in_level):
                node = q.popleft()
                level.append(node.val)

                if node.left:
                    q.append(node.left)         

                if node.right:
                    q.append(node.right)   


            result_list.append(level)
        return result_list

# %%
# Development

# %%
root = [1,2,3,4,"null","null",5]

# %%
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
# Help function to build the tree by levels from the list representation
from collections import deque

def build_tree_by_levels(list_obj):
    if len(list_obj) == 0:
        return []

    q = deque()
    tree = TreeNode(list_obj[0])
    q.append(tree)

    i = 1
    while q and i < len(list_obj):
        node = q.popleft()
        if list_obj[i]!= "null":
            node.left = TreeNode(list_obj[i])
            q.append(node.left)

        i+=1
        if list_obj[i]!="null":
            node.right = TreeNode(list_obj[i])
            q.append(node.right)

        i+=1

    return tree

tree = build_tree_by_levels(root)
tree

# %%
def level_traversal(tree):
    if not tree:
        return []

    result_list = []
    q = deque([tree])

    while q:
        objects_in_level = len(q)        
        level = []

        for _ in range(objects_in_level):
            node = q.popleft()
            level.append(node.val)

            if node.left:
                q.append(node.left)         

            if node.right:
                q.append(node.right)   


        result_list.append(level)
    return result_list
        
result = level_traversal(tree)   
result
# Out:
# [[1], [2, 3], [4, 5]]
