# %% [markdown]
# 8. String to Integer (atoi)

# %% [markdown]
# Implement the myAtoi(string s) function, which converts a string to a 32-bit signed integer.
#
# The algorithm for myAtoi(string s) is as follows:
#
# Whitespace: Ignore any leading whitespace (" ").
# Signedness: Determine the sign by checking if the next character is '-' or '+', assuming positivity if neither present.
# Conversion: Read the integer by skipping leading zeros until a non-digit character is encountered or the end of the string is reached. If no digits were read, then the result is 0.
# Rounding: If the integer is out of the 32-bit signed integer range [-231, 231 - 1], then round the integer to remain in the range. Specifically, integers less than -231 should be rounded to -231, and integers greater than 231 - 1 should be rounded to 231 - 1.
# Return the integer as the final result.

# %% [markdown]
# ![image.png](attachment:faaa3609-3a8c-4642-82a4-33df8e0795d6.png)

# %% [markdown]
# ![image.png](attachment:74a72090-252b-43da-ac93-76b1e192afb1.png)

# %% [markdown]
# ![image.png](attachment:2ad46452-1c67-4b9f-a236-4d8a5be68333.png)

# %% [markdown]
# ![image.png](attachment:ca7ee9ae-17fd-49e2-8a0d-6694d6a5e049.png)

# %% [markdown]
# ![image.png](attachment:e6d47c68-8a9c-403c-868f-27be2f3638fe.png)

# %%
class Solution(object):
    def myAtoi(self, s):
        """
        :type s: str
        :rtype: int
        """
        n = len(s)
        if n == 0:
            return 0
            
        MAX_LIMIT = 2**31 - 1
        MIN_LIMIT = -2**31
        
        res = 0
        sign = 1
        i= 0
        while i < n and s[i] == " ":
            i+=1            
            
        if i < n and  s[i] in"-+":
            sign = -1 if s[i] == "-" else 1
            i+=1
    
        while i < n and s[i].isdigit():
            res = res * 10 + int(s[i])
            i += 1

        res = sign * res
        if res > MAX_LIMIT:
            res = MAX_LIMIT
            
        if res < MIN_LIMIT:
            res = MIN_LIMIT
            
        return res

# %%
# Development

# %%
s = " -1"

# %%
def myAtoi(s):
    n = len(s)
    if n == 0:
        return 0
        
    MAX_LIMIT = 2**31 - 1
    MIN_LIMIT = -2**31
    
    res = 0
    sign = 1
    i= 0
    while i < n and s[i] == " ":
        i+=1
        
    	
    if i < n and  s[i] in"-+":
        sign = -1 if s[i] == "-" else 1
        i+=1

 
    while i < n and s[i].isdigit():
        res = res * 10 + int(s[i])
        i += 1

    res = sign * res
    if res > MAX_LIMIT:
        res = MAX_LIMIT

    if res < MIN_LIMIT:
        res = MIN_LIMIT
        
    return res

# %%
myAtoi(s)
# Out:
# -1
